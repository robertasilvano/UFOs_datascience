# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

pd.options.mode.chained_assignment = None

# %%
file_name = 'pre_processado_completo.csv'

df = pd.read_csv(file_name, header=0, error_bad_lines=False, warn_bad_lines=False, low_memory=False)

# %%
df.head()
# Out:
#                    city state country     shape  duration_m  \
# 0            san marcos    tx      us  cylinder   45.000000
# 1  chester (uk/england)   NaN      gb    circle    0.333333
# 2                  edna    tx      us    circle    0.333333
# 3               kaneohe    hi      us     light   15.000000
# 4               bristol    tn      us    sphere    5.000000
#
#                                                                                                                   comments  \
# 0  This event took place in early fall around 1949-50. It occurred after a Boy Scout meeting in the Baptist Church. The...
# 1                                                                      Green/Orange circular disc over Chester&#44 England
# 2  My older brother and twin sister were leaving the only Edna theater at about 9 PM&#44...we had our bikes and I took ...
# 3  AS a Marine 1st Lt. flying an FJ4B fighter/attack aircraft on a solo night exercise&#44 I was at 50&#44000&#39 in a ...
# 4  My father is now 89 my brother 52 the girl with us now 51 myself 49 and the other fellow which worked with my father...
#
#     latitude   longitude        date
# 0  29.883056  -97.941111  1949-10-10
# 1  53.200000   -2.916667  1955-10-10
# 2  28.978333  -96.645833  1956-10-10
# 3  21.418056 -157.803611  1960-10-10
# 4  36.595000  -82.188889  1961-10-10

# %%
# define um array com as latitudes e longitudes

lat_lon = np.array(df[['longitude', 'latitude']]).astype(float)
print(len(lat_lon))
print(lat_lon)
# Out:
# 85796
# [[-97.9411111  29.8830556]
#  [ -2.916667   53.2      ]
#  [-96.6458333  28.9783333]
#  ...
#  [-74.163755   40.858433 ]
#  [ 22.891814   50.465843 ]
#  [-77.710548   34.367594 ]]

# %% [markdown]
# ### Analise por país

# %%
# define uma lista com os países, e calcula o peso de cada país de acordo com a quantidade de avistamentos, pelo método count

countrys = list(df['country'])
pesos = [countrys.count(c) for c in countrys]

# %%
scaler = MinMaxScaler()

# %%
# aplica o elbow criteria

sse = {}
for k in range(2, 50):
    kmeans = KMeans(n_clusters=k, max_iter=2000).fit(scaler.fit_transform(lat_lon), sample_weight=pesos)
    sse[k] = kmeans.inertia_
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# ### Visto que o range para o Elbow Criteria foi grande, o número adequado de clusters está entre 5 e 25
# #### A soma dos erros quadráticos não apresenta decaimento significante a partir desses valores, logo o gasto computacional para k_clusters maiores não se torna viável

# %% [markdown]
# ### Para definir o melhor valor nesse range, foi utilizado o Coeficiente de Silhouette
# #### quanto maior o coeficiente, menor a distância intracluster e maior a distância intercluster

# %%
# aplica o coeficiente de silhouette

for k in range(5, 25):
    kmeans = KMeans(n_clusters=k, max_iter=2000).fit(scaler.fit_transform(lat_lon), sample_weight=pesos)
    label = kmeans.labels_
    sil_coeff = metrics.silhouette_score(scaler.fit_transform(lat_lon), label, metric='euclidean')
    print("Para n_clusters={}, o coeficiente de  Silhouette {}".format(k, sil_coeff))
# Out:
# Para n_clusters=5, o coeficiente de  Silhouette 0.47229884143722806
# Para n_clusters=6, o coeficiente de  Silhouette 0.5345508805804804
# Para n_clusters=7, o coeficiente de  Silhouette 0.46356132466787814
# Para n_clusters=8, o coeficiente de  Silhouette 0.47769676208759515
# Para n_clusters=9, o coeficiente de  Silhouette 0.46951368377996205
# Para n_clusters=10, o coeficiente de  Silhouette 0.47546495428282715
# Para n_clusters=11, o coeficiente de  Silhouette 0.45365900558405164
# Para n_clusters=12, o coeficiente de  Silhouette 0.4764576160254202
# Para n_clusters=13, o coeficiente de  Silhouette 0.4728844050479172
# Para n_clusters=14, o coeficiente de  Silhouette 0.48480993939830325
# Para n_clusters=15, o coeficiente de  Silhouette 0.4792413749424267
# Para n_clusters=16, o coeficiente de  Silhouette 0.4640496157203891
# Para n_clusters=17, o coeficiente de  Silhouette 0.487009954967951
# Para n_clusters=18, o coeficiente de  Silhouette 0.4789104204515416
# Para n_clusters=19, o coeficiente de  Silhouette 0.49446952971587016
# Para n_clusters=20, o coeficiente de  Silhouette 0.4912826107663703
# Para n_clusters=21, o coeficiente de  Silhouette 0.4797734729788684
# Para n_clusters=22, o coeficiente de  Silhouette 0.4729098651429632
# Para n_clusters=23, o coeficiente de  Silhouette 0.4667617416504283
# Para n_clusters=24, o coeficiente de  Silhouette 0.4637201694675347

# %% [markdown]
# ### De acordo com o Coeficiente de Silhouette o número adequado de clusters é em torno de 8

# %%
# aplica o algoritmo kmeans, utilizando os pesos e normalizando os valores

kmeans = KMeans(n_clusters=8, max_iter=2000)
kmeans.fit(scaler.fit_transform(lat_lon), sample_weight=pesos)
lat_lon_scaled = np.array(scaler.fit_transform(lat_lon))
lat_lon_scaled
# Out:
# array([[0.22167546, 0.64053565],
#        [0.4892746 , 0.83629017],
#        [0.2253231 , 0.63294017],
#        ...,
#        [0.28863507, 0.73267807],
#        [0.56195408, 0.81333589],
#        [0.27864692, 0.67818504]])

# %%
centers = kmeans.cluster_centers_
centers
# Out:
# array([[0.27026027, 0.73918619],
#        [0.896639  , 0.11668497],
#        [0.49310659, 0.83208017],
#        [0.16958473, 0.68875288],
#        [0.15582374, 0.78475458],
#        [0.25275875, 0.63102747],
#        [0.83076068, 0.5301562 ],
#        [0.25062002, 0.68876456]])

# %%
locations = kmeans.labels_.astype(float)
print(len(locations))
locations
# Out:
# 85796
# array([5., 2., 5., ..., 0., 2., 7.])

# %%
fig, ax = plt.subplots(figsize=(15, 10))
scatter = ax.scatter(lat_lon_scaled[:, 0], lat_lon_scaled[:, 1], c=locations, cmap='rainbow')
ax.scatter(centers[:, 0], centers[:, 1], c='black', s=100)
fig.suptitle('Locais de avistamento no mundo')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
# Out:
# Text(0, 0.5, 'Longitude')

# %%
fig, ax = plt.subplots(figsize=(15, 10))
scatter = ax.scatter(lat_lon_scaled[:, 0], lat_lon_scaled[:, 1], c=pesos, cmap='rainbow')
ax.scatter(centers[:, 0], centers[:, 1], c='black', s=100)
fig.suptitle('Locais de avistamento no mundo')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
# Out:
# Text(0, 0.5, 'Longitude')

# %%
geolocator = Nominatim(user_agent="geoapiExercises")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
reverse = RateLimiter(geolocator.reverse, min_delay_seconds=1)

# %%
centers_notscaled = scaler.inverse_transform(centers)
centers_notscaled = centers_notscaled.tolist()

for i in range(len(centers_notscaled)):
    centers_notscaled[i][0], centers_notscaled[i][1] = centers_notscaled[i][1], centers_notscaled[i][0]

centers_notscaled = [tuple(center) for center in centers_notscaled]
centers_notscaled
# Out:
# [(41.6336357492313, -80.68864527783344),
#  (-32.51446850201859, 141.73841316186554),
#  (52.69853436420064, -1.5559271789248357),
#  (35.626363608884354, -116.43852396370114),
#  (47.061432551983664, -121.32505292548828),
#  (28.750506420836004, -86.90343451233664),
#  (16.735407479396976, 118.34502525821038),
#  (35.62775451957296, -87.66289886617821)]

# %%
address = [reverse(loc) for loc in centers_notscaled]

# %%
centers_countrys = []
for i in range(12):
    try:
        centers_countrys.append(address[i].raw['address']['country'])
    except:
        centers_countrys.append('NULL')
centers_countrys
# Out:
# ['United States',
#  'Australia',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'NULL',
#  'NULL',
#  'NULL',
#  'NULL']

# %%
locations = list(locations)
locations = [int(item) for item in locations]
centers_countrys_all = [centers_countrys[loc] for loc in locations]
centers_countrys_all
# Out:
# ['NULL',
#  'United Kingdom',
#  'NULL',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'Australia',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'Australia',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'Australia',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'Australia',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'NULL',
#  'United States',
#  'United Kingdom',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United Kingdom',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'Australia',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'Australia',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'Australia',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'NULL',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'Australia',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  ...]

# %%
pd.set_option("max_colwidth", 120)
df['pesos'] = pesos
df['k-countrys'] = centers_countrys_all
df['k-centers'] = locations
df[['country', 'pesos', 'k-countrys', 'k-centers']].head(15)
# Out:
#    country  pesos      k-countrys  k-centers
# 0       us  75982            NULL          5
# 1       gb   2524  United Kingdom          2
# 2       us  75982            NULL          5
# 3       us  75982   United States          3
# 4       us  75982   United States          7
# 5       gb   2524  United Kingdom          2
# 6       us  75982   United States          0
# 7       us  75982   United States          7
# 8       us  75982            NULL          5
# 9       us  75982   United States          3
# 10      us  75982   United States          7
# 11      us  75982   United States          0
# 12      us  75982   United States          7
# 13      us  75982   United States          7
# 14      us  75982   United States          7
