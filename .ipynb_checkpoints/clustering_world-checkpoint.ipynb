# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
file_name = 'pre_processado_completo.csv'

df = pd.read_csv(file_name, header=0, error_bad_lines=False, warn_bad_lines=False, low_memory=False)

# %%
df.head()
# Out:
#                    city state country     shape  duration_m  \
# 0            san marcos    tx      us  cylinder   45.000000
# 1          lackland afb    tx     NaN     light  120.000000
# 2  chester (uk/england)   NaN      gb    circle    0.333333
# 3                  edna    tx      us    circle    0.333333
# 4               kaneohe    hi      us     light   15.000000
#
#                                                                                                                   comments  \
# 0  This event took place in early fall around 1949-50. It occurred after a Boy Scout meeting in the Baptist Church. The...
# 1                          1949 Lackland AFB&#44 TX.  Lights racing across the sky &amp; making 90 degree turns on a dime.
# 2                                                                      Green/Orange circular disc over Chester&#44 England
# 3  My older brother and twin sister were leaving the only Edna theater at about 9 PM&#44...we had our bikes and I took ...
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/attack aircraft on a solo night exercise&#44 I was at 50&#44000&#39 in a ...
#
#     latitude   longitude        date
# 0  29.883056  -97.941111  1949-10-10
# 1  29.384210  -98.581082  1949-10-10
# 2  53.200000   -2.916667  1955-10-10
# 3  28.978333  -96.645833  1956-10-10
# 4  21.418056 -157.803611  1960-10-10

# %%
# define um array com as latitudes e longitudes

lat_lon = np.array(df[['longitude', 'latitude']]).astype(float)
print(len(lat_lon))
print(lat_lon)
# Out:
# 88673
# [[-97.9411111  29.8830556]
#  [-98.581082   29.38421  ]
#  [ -2.916667   53.2      ]
#  ...
#  [-97.4777778  35.6527778]
#  [-82.6958333  34.3769444]
#  [-80.1436111  26.1219444]]

# %% [markdown]
# ### Analise por estados

# %%
# define uma lista com os estados, e calcula o peso de cada estado de acordo com a quantidade de avistamentos, pelo método count

states = list(df['state'])
pesos_s = [states.count(s) for s in states]

# %%
scaler = MinMaxScaler()

# %%
# aplica o elbow criteria

sse = {}
for k in range(2, 50):
    kmeans = KMeans(n_clusters=k, max_iter=2000).fit(scaler.fit_transform(lat_lon), sample_weight=pesos_s)
    sse[k] = kmeans.inertia_
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# ### Visto que o range para o Elbow Criteria foi grande, o número adequado de clusters está entre 5 e 20
# #### A soma dos erros quadráticos não apresenta decaimento significante a partir desses valores, logo o gasto computacional para k_clusters maiores não se torna viável

# %% [markdown]
# ### Para definir o melhor valor nesse range, foi utilizado o Coeficiente de Silhouette
# #### quanto maior o coeficiente, menor a distância intracluster e maior a distância intercluster

# %%
# aplica o coeficiente de silhouette

for k in range(5, 20):
    kmeans = KMeans(n_clusters=k, max_iter=2000).fit(scaler.fit_transform(lat_lon), sample_weight=pesos_s)
    label = kmeans.labels_
    sil_coeff = metrics.silhouette_score(scaler.fit_transform(lat_lon), label, metric='euclidean')
    print("Para n_clusters={}, o coeficiente de  Silhouette {}".format(k, sil_coeff))
# Out:
# Para n_clusters=5, o coeficiente de  Silhouette 0.5312048697121609
# Para n_clusters=6, o coeficiente de  Silhouette 0.5374589390876062
# Para n_clusters=7, o coeficiente de  Silhouette 0.4987885976923663
# Para n_clusters=8, o coeficiente de  Silhouette 0.5362444536699965
# Para n_clusters=9, o coeficiente de  Silhouette 0.5335383391312584
# Para n_clusters=10, o coeficiente de  Silhouette 0.5003200301893481
# Para n_clusters=11, o coeficiente de  Silhouette 0.47692061606598524
# Para n_clusters=12, o coeficiente de  Silhouette 0.4620942585723777
# Para n_clusters=13, o coeficiente de  Silhouette 0.4372379189059276
# Para n_clusters=14, o coeficiente de  Silhouette 0.4795034438299888
# Para n_clusters=15, o coeficiente de  Silhouette 0.44079064769282345
# Para n_clusters=16, o coeficiente de  Silhouette 0.505151270430281
# Para n_clusters=17, o coeficiente de  Silhouette 0.4887000219005324
# Para n_clusters=18, o coeficiente de  Silhouette 0.44108517248029694
# Para n_clusters=19, o coeficiente de  Silhouette 0.5009378615927571

# %% [markdown]
# ### De acordo com o Score Silhouette o número adequado de clusters é em torno de 8

# %%
# aplica o algoritmo kmeans, utilizando os pesos e normalizando os valores

kmeans = KMeans(n_clusters=8, max_iter=2000)
kmeans.fit(scaler.fit_transform(lat_lon), sample_weight=pesos_s)
lat_lon_scaled = np.array(scaler.fit_transform(lat_lon))
lat_lon_scaled
# Out:
# array([[0.22167546, 0.72476095],
#        [0.21987323, 0.72155423],
#        [0.4892746 , 0.87464866],
#        ...,
#        [0.22298025, 0.7618503 ],
#        [0.26460781, 0.7536489 ],
#        [0.27179515, 0.70058349]])

# %%
centers = kmeans.cluster_centers_
centers
# Out:
# array([[0.16404654, 0.76158093],
#        [0.50630877, 0.85929592],
#        [0.26870515, 0.7951081 ],
#        [0.91172723, 0.31983763],
#        [0.75287321, 0.66927596],
#        [0.48474531, 0.49893768],
#        [0.15487633, 0.83470784],
#        [0.25021946, 0.71797391]])

# %%
locations = kmeans.labels_.astype(float)
print(len(locations))
locations
# Out:
# 88673
# array([7., 7., 1., ..., 7., 7., 7.])

# %%
fig, ax = plt.subplots(figsize=(15, 10))
scatter = ax.scatter(lat_lon_scaled[:, 0], lat_lon_scaled[:, 1], c=pesos_s, cmap='rainbow')
ax.scatter(centers[:, 0], centers[:, 1], c='black', s=100)
fig.suptitle('Locais de avistamento no mundo')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
# Out:
# Text(0, 0.5, 'Longitude')

# %%
geolocator = Nominatim(user_agent="geoapiExercises")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
reverse = RateLimiter(geolocator.reverse, min_delay_seconds=1)

# %%
centers_notscaled = scaler.inverse_transform(centers)
centers_notscaled = centers_notscaled.tolist()

for i in range(len(centers_notscaled)):
    centers_notscaled[i][0], centers_notscaled[i][1] = centers_notscaled[i][1], centers_notscaled[i][0]

centers_notscaled = [tuple(center) for center in centers_notscaled]
centers_notscaled
# Out:
# [(35.61087382878512, -118.40513512783163),
#  (50.81168651261855, 3.1321663246566462),
#  (40.82645277341389, -81.24086818852452),
#  (-33.1079294998044, 147.09624463472986),
#  (21.251658186800878, 90.68718774535918),
#  (-5.246633538442225, -4.52501732326462),
#  (46.98669687870085, -121.66147944320103),
#  (28.8272448598861, -87.80513688038835)]

# %%
address = [reverse(loc) for loc in centers_notscaled]

# %%
centers_states = []
for i in range(12):
    try:
        centers_states.append(address[i].raw['address']['state'])
    except:
        centers_states.append('NULL')
centers_states
# Out:
# ['California',
#  'West-Vlaanderen',
#  'Ohio',
#  'New South Wales',
#  'NULL',
#  'NULL',
#  'Washington',
#  'NULL',
#  'NULL',
#  'NULL',
#  'NULL',
#  'NULL']

# %%
locations = list(locations)
locations = [int(item) for item in locations]
centers_states_all = [centers_states[loc] for loc in locations]
centers_states_all
# Out:
# ['NULL',
#  'NULL',
#  'West-Vlaanderen',
#  'NULL',
#  'California',
#  'Ohio',
#  'West-Vlaanderen',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'West-Vlaanderen',
#  'Ohio',
#  'NULL',
#  'Washington',
#  'West-Vlaanderen',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'California',
#  'California',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'New South Wales',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'West-Vlaanderen',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Washington',
#  'California',
#  'Washington',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'West-Vlaanderen',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'California',
#  'Ohio',
#  'New South Wales',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'California',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'California',
#  'California',
#  'Ohio',
#  'California',
#  'California',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'California',
#  'Washington',
#  'California',
#  'Ohio',
#  'California',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Washington',
#  'Ohio',
#  'New South Wales',
#  'Washington',
#  'California',
#  'Ohio',
#  'California',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'New South Wales',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'NULL',
#  'New South Wales',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'NULL',
#  'California',
#  'West-Vlaanderen',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'West-Vlaanderen',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'California',
#  'NULL',
#  'NULL',
#  'California',
#  'Ohio',
#  'West-Vlaanderen',
#  'Ohio',
#  'NULL',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'West-Vlaanderen',
#  'NULL',
#  'California',
#  'Ohio',
#  'Washington',
#  'Washington',
#  'NULL',
#  'California',
#  'NULL',
#  'California',
#  'California',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'NULL',
#  'NULL',
#  'NULL',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'California',
#  'Ohio',
#  'NULL',
#  'California',
#  'West-Vlaanderen',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'California',
#  'California',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'California',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'California',
#  'Ohio',
#  'California',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'California',
#  'Ohio',
#  'California',
#  'NULL',
#  'California',
#  'Ohio',
#  'California',
#  'California',
#  'Ohio',
#  'West-Vlaanderen',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'California',
#  'California',
#  'Washington',
#  'NULL',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'California',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'New South Wales',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'California',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'West-Vlaanderen',
#  'NULL',
#  'California',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'NULL',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Washington',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'West-Vlaanderen',
#  'Ohio',
#  'California',
#  'West-Vlaanderen',
#  'California',
#  'Ohio',
#  'Washington',
#  'California',
#  'NULL',
#  'California',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'NULL',
#  'California',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'California',
#  'Ohio',
#  'Ohio',
#  'California',
#  'California',
#  'Washington',
#  'Ohio',
#  'California',
#  'NULL',
#  'California',
#  'California',
#  'California',
#  'Ohio',
#  'NULL',
#  'Washington',
#  'NULL',
#  'Ohio',
#  'West-Vlaanderen',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'West-Vlaanderen',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Washington',
#  'California',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'West-Vlaanderen',
#  'California',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Washington',
#  'New South Wales',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'West-Vlaanderen',
#  'West-Vlaanderen',
#  'California',
#  'NULL',
#  'California',
#  'Ohio',
#  'New South Wales',
#  'Ohio',
#  'Ohio',
#  'California',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'California',
#  'California',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Washington',
#  'Ohio',
#  'NULL',
#  'California',
#  'Ohio',
#  'California',
#  'California',
#  'California',
#  'Ohio',
#  'Ohio',
#  'California',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Washington',
#  'Ohio',
#  'California',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'California',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'NULL',
#  'Ohio',
#  'New South Wales',
#  'California',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Washington',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'California',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'West-Vlaanderen',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'California',
#  'California',
#  'California',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'West-Vlaanderen',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'California',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'West-Vlaanderen',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'California',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Washington',
#  'California',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'California',
#  'NULL',
#  'California',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'California',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'West-Vlaanderen',
#  'West-Vlaanderen',
#  'California',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'California',
#  'Ohio',
#  'California',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'California',
#  'California',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'California',
#  'Washington',
#  'Washington',
#  'Washington',
#  'California',
#  'California',
#  'Ohio',
#  'California',
#  'Ohio',
#  'California',
#  'California',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'West-Vlaanderen',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'California',
#  'California',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'West-Vlaanderen',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'California',
#  'California',
#  'California',
#  'California',
#  'Washington',
#  'West-Vlaanderen',
#  'Ohio',
#  'California',
#  'NULL',
#  'California',
#  'Ohio',
#  'New South Wales',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'California',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'California',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Ohio',
#  'West-Vlaanderen',
#  'California',
#  'Washington',
#  'California',
#  'Washington',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'California',
#  'Washington',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'California',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'California',
#  'Washington',
#  'California',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'California',
#  'California',
#  'Ohio',
#  'California',
#  'NULL',
#  'West-Vlaanderen',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'California',
#  'NULL',
#  'California',
#  'California',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'California',
#  'Ohio',
#  'California',
#  'Ohio',
#  'NULL',
#  'West-Vlaanderen',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'California',
#  'West-Vlaanderen',
#  'NULL',
#  'California',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'Ohio',
#  'California',
#  'NULL',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Ohio',
#  'NULL',
#  'Washington',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'Ohio',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'NULL',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'Ohio',
#  'Ohio',
#  'New South Wales',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'California',
#  'Washington',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'California',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'NULL',
#  'Washington',
#  'California',
#  'Washington',
#  'Washington',
#  'NULL',
#  'Ohio',
#  'Washington',
#  'Washington',
#  'Washington',
#  'NULL',
#  'West-Vlaanderen',
#  'Washington',
#  'Ohio',
#  'NULL',
#  'California',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  'California',
#  'NULL',
#  'NULL',
#  'California',
#  'NULL',
#  'Ohio',
#  'Ohio',
#  'Washington',
#  'Ohio',
#  'NULL',
#  'NULL',
#  'Ohio',
#  ...]

# %%
pd.set_option("max_colwidth", 120)
df['pesos'] = pesos
df['k-states'] = centers_states_all
df['k-centers'] = locations
df[['state', 'country', 'pesos', 'k-states', 'k-centers']].head(15)
# Out:
#    state country  pesos         k-states  k-centers
# 0     tx      us   4041             NULL          7
# 1     tx     NaN   4041             NULL          7
# 2    NaN      gb   7407  West-Vlaanderen          1
# 3     tx      us   4041             NULL          7
# 4     hi      us    383       California          0
# 5     tn      us   1310             Ohio          2
# 6    NaN      gb   7407  West-Vlaanderen          1
# 7     ct      us   1061             Ohio          2
# 8     al      us    763             NULL          7
# 9     fl      us   4596             NULL          7
# 10    ca      us  10448       California          0
# 11    nc      us   2018             Ohio          2
# 12    ny      us   3506             Ohio          2
# 13    ky      us   1000             Ohio          2
# 14    nc      us   2018             Ohio          2

# %% [markdown]
# ### Analise por país

# %%
# define uma lista com os estados, e calcula o peso de cada estado de acordo com a quantidade de avistamentos, pelo método count

countrys = list(df['country'])
pesos_c = [countrys.count(c) for c in countrys]

# %%
scaler = MinMaxScaler()

# %%
# aplica o elbow criteria

sse = {}
for k in range(2, 50):
    kmeans = KMeans(n_clusters=k, max_iter=2000).fit(scaler.fit_transform(lat_lon), sample_weight=pesos_c)
    sse[k] = kmeans.inertia_
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# ### Visto que o range para o Elbow Criteria foi grande, o número adequado de clusters está entre 5 e 25
# #### A soma dos erros quadráticos não apresenta decaimento significante a partir desses valores, logo o gasto computacional para k_clusters maiores não se torna viável

# %% [markdown]
# ### Para definir o melhor valor nesse range, foi utilizado o Coeficiente de Silhouette
# #### quanto maior o coeficiente, menor a distância intracluster e maior a distância intercluster

# %%
# aplica o coeficiente de silhouette

for k in range(5, 25):
    kmeans = KMeans(n_clusters=k, max_iter=2000).fit(scaler.fit_transform(lat_lon), sample_weight=pesos_c)
    label = kmeans.labels_
    sil_coeff = metrics.silhouette_score(scaler.fit_transform(lat_lon), label, metric='euclidean')
    print("Para n_clusters={}, o coeficiente de  Silhouette {}".format(k, sil_coeff))
# Out:
# Para n_clusters=5, o coeficiente de  Silhouette 0.46598316840529724
# Para n_clusters=6, o coeficiente de  Silhouette 0.4897882658227698
# Para n_clusters=7, o coeficiente de  Silhouette 0.5258168934605912
# Para n_clusters=8, o coeficiente de  Silhouette 0.5313451159941194
# Para n_clusters=9, o coeficiente de  Silhouette 0.49102312490102323
# Para n_clusters=10, o coeficiente de  Silhouette 0.4595092735305331
# Para n_clusters=11, o coeficiente de  Silhouette 0.4810090414515804
# Para n_clusters=12, o coeficiente de  Silhouette 0.5036531951849171
# Para n_clusters=13, o coeficiente de  Silhouette 0.5085155991356703
# Para n_clusters=14, o coeficiente de  Silhouette 0.509036771337527
# Para n_clusters=15, o coeficiente de  Silhouette 0.49886548703997974
# Para n_clusters=16, o coeficiente de  Silhouette 0.47910414097105325
# Para n_clusters=17, o coeficiente de  Silhouette 0.5192344391342331
# Para n_clusters=18, o coeficiente de  Silhouette 0.5173712567867976
# Para n_clusters=19, o coeficiente de  Silhouette 0.49335351503911357
# Para n_clusters=20, o coeficiente de  Silhouette 0.496358612012683
# Para n_clusters=21, o coeficiente de  Silhouette 0.49649291059007394
# Para n_clusters=22, o coeficiente de  Silhouette 0.4767411325565375
# Para n_clusters=23, o coeficiente de  Silhouette 0.4703146085316884
# Para n_clusters=24, o coeficiente de  Silhouette 0.4912047346505454

# %%
# aplica o coeficiente de silhouette
# pra mim na vdd ta entre 15 e 25 aí rodei tudo aqui embaixo pra confirmar mas deu 8 mesmo. deixei aqui pra ti analisar
# pq ainda estou desconfiada rs

for k in range(2, 50):
    kmeans = KMeans(n_clusters=k, max_iter=2000).fit(scaler.fit_transform(lat_lon), sample_weight=pesos_c)
    label = kmeans.labels_
    sil_coeff = metrics.silhouette_score(scaler.fit_transform(lat_lon), label, metric='euclidean')
    print("Para n_clusters={}, o coeficiente de  Silhouette {}".format(k, sil_coeff))
# Out:
# Para n_clusters=2, o coeficiente de  Silhouette 0.32163981936642
# Para n_clusters=3, o coeficiente de  Silhouette 0.4516715032745854
# Para n_clusters=4, o coeficiente de  Silhouette 0.3827590405592425
# Para n_clusters=5, o coeficiente de  Silhouette 0.5319820538588717
# Para n_clusters=6, o coeficiente de  Silhouette 0.4897882658227698
# Para n_clusters=7, o coeficiente de  Silhouette 0.5258700396145566
# Para n_clusters=8, o coeficiente de  Silhouette 0.5331172866779205
# Para n_clusters=9, o coeficiente de  Silhouette 0.4903310925691176
# Para n_clusters=10, o coeficiente de  Silhouette 0.4620663927745964
# Para n_clusters=11, o coeficiente de  Silhouette 0.49592011583260964
# Para n_clusters=12, o coeficiente de  Silhouette 0.4930959779880314
# Para n_clusters=13, o coeficiente de  Silhouette 0.49743876541659005
# Para n_clusters=14, o coeficiente de  Silhouette 0.4762036209631907
# Para n_clusters=15, o coeficiente de  Silhouette 0.5104880911600669
# Para n_clusters=16, o coeficiente de  Silhouette 0.5011955605922176
# Para n_clusters=17, o coeficiente de  Silhouette 0.5167437675406359
# Para n_clusters=18, o coeficiente de  Silhouette 0.5172014295230047
# Para n_clusters=19, o coeficiente de  Silhouette 0.5188275197527751
# Para n_clusters=20, o coeficiente de  Silhouette 0.4959969651486562
# Para n_clusters=21, o coeficiente de  Silhouette 0.4909351952427092
# Para n_clusters=22, o coeficiente de  Silhouette 0.5143551979247419
# Para n_clusters=23, o coeficiente de  Silhouette 0.48516709032687216
# Para n_clusters=24, o coeficiente de  Silhouette 0.4994312963132761
# Para n_clusters=25, o coeficiente de  Silhouette 0.4809778486799897
# Para n_clusters=26, o coeficiente de  Silhouette 0.4943014532052527
# Para n_clusters=27, o coeficiente de  Silhouette 0.48479277275437865
# Para n_clusters=28, o coeficiente de  Silhouette 0.49031874854164575
# Para n_clusters=29, o coeficiente de  Silhouette 0.46468043686414906
# Para n_clusters=30, o coeficiente de  Silhouette 0.4704998843756008
# Para n_clusters=31, o coeficiente de  Silhouette 0.4759499242028384
# Para n_clusters=32, o coeficiente de  Silhouette 0.46114186892859216
# Para n_clusters=33, o coeficiente de  Silhouette 0.48816725576528347
# Para n_clusters=34, o coeficiente de  Silhouette 0.4596223096738737
# Para n_clusters=35, o coeficiente de  Silhouette 0.47460161045456106
# Para n_clusters=36, o coeficiente de  Silhouette 0.46059465593379423
# Para n_clusters=37, o coeficiente de  Silhouette 0.47194262948612137
# Para n_clusters=38, o coeficiente de  Silhouette 0.4606886728882162
# Para n_clusters=39, o coeficiente de  Silhouette 0.46452946300713344
# Para n_clusters=40, o coeficiente de  Silhouette 0.46904863093516985
# Para n_clusters=41, o coeficiente de  Silhouette 0.46972028153930956
# Para n_clusters=42, o coeficiente de  Silhouette 0.45663381685725235
# Para n_clusters=43, o coeficiente de  Silhouette 0.46919792268009236
# Para n_clusters=44, o coeficiente de  Silhouette 0.468692504426686
# Para n_clusters=45, o coeficiente de  Silhouette 0.47795066906966843
# Para n_clusters=46, o coeficiente de  Silhouette 0.46254732756296085
# Para n_clusters=47, o coeficiente de  Silhouette 0.46613314731766364
# Para n_clusters=48, o coeficiente de  Silhouette 0.47630759643376014
# Para n_clusters=49, o coeficiente de  Silhouette 0.46258625755139504

# %% [markdown]
# ### De acordo com o Coeficiente de Silhouette o número adequado de clusters é em torno de 8

# %%
# aplica o algoritmo kmeans, utilizando os pesos e normalizando os valores

kmeans = KMeans(n_clusters=8, max_iter=2000)
kmeans.fit(scaler.fit_transform(lat_lon), sample_weight=pesos_c)
lat_lon_scaled = np.array(scaler.fit_transform(lat_lon))
lat_lon_scaled
# Out:
# array([[0.22167546, 0.72476095],
#        [0.21987323, 0.72155423],
#        [0.4892746 , 0.87464866],
#        ...,
#        [0.22298025, 0.7618503 ],
#        [0.26460781, 0.7536489 ],
#        [0.27179515, 0.70058349]])

# %%
centers = kmeans.cluster_centers_
centers
# Out:
# array([[0.2504153 , 0.73687699],
#        [0.26759883, 0.79637614],
#        [0.76165465, 0.66359953],
#        [0.15556718, 0.83505939],
#        [0.51946131, 0.84657719],
#        [0.48609896, 0.50469522],
#        [0.93651121, 0.31668154],
#        [0.17016355, 0.76188053]])

# %%
locations = kmeans.labels_.astype(float)
print(len(locations))
locations
# Out:
# 88673
# array([0., 0., 4., ..., 0., 0., 0.])

# %%
fig, ax = plt.subplots(figsize=(15, 10))
scatter = ax.scatter(lat_lon_scaled[:, 0], lat_lon_scaled[:, 1], c=pesos_c, cmap='rainbow')
ax.scatter(centers[:, 0], centers[:, 1], c='black', s=100)
fig.suptitle('Locais de avistamento no mundo')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
# Out:
# Text(0, 0.5, 'Longitude')

# %%
geolocator = Nominatim(user_agent="geoapiExercises")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
reverse = RateLimiter(geolocator.reverse, min_delay_seconds=1)

# %%
centers_notscaled = scaler.inverse_transform(centers)
centers_notscaled = centers_notscaled.tolist()

for i in range(len(centers_notscaled)):
    centers_notscaled[i][0], centers_notscaled[i][1] = centers_notscaled[i][1], centers_notscaled[i][0]

centers_notscaled = [tuple(center) for center in centers_notscaled]
centers_notscaled
# Out:
# [(31.76786048249267, -87.73559271390533),
#  (41.02371233160509, -81.63372272075695),
#  (20.368617612667475, 93.80547587819724),
#  (47.04138523988779, -121.41615862505964),
#  (48.83312599341125, 7.80263338027714),
#  (-4.350975226931125, -4.044336726394592),
#  (-33.59890087350261, 155.8970328792722),
#  (35.65747924071102, -116.23298643675716)]

# %%
address = [reverse(loc) for loc in centers_notscaled]

# %%
centers_countrys = []
for i in range(12):
    try:
        centers_countrys.append(address[i].raw['address']['country'])
    except:
        centers_countrys.append('NULL')
centers_countrys
# Out:
# ['United States',
#  'United States',
#  'မြန်မာ',
#  'United States',
#  'France',
#  'NULL',
#  'NULL',
#  'United States',
#  'NULL',
#  'NULL',
#  'NULL',
#  'NULL']

# %%
locations = list(locations)
locations = [int(item) for item in locations]
centers_countrys_all = [centers_countrys[loc] for loc in locations]
centers_countrys_all
# Out:
# ['United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'မြန်မာ',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'မြန်မာ',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'မြန်မာ',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'မြန်မာ',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'NULL',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'မြန်မာ',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'France',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  ...]

# %%
pd.set_option("max_colwidth", 120)
df['pesos'] = pesos
df['k-countrys'] = centers_countrys_all
df['k-centers'] = locations
df[['country', 'pesos', 'k-countrys', 'k-centers']].head(15)
# Out:
#    country  pesos     k-countrys  k-centers
# 0       us   4041  United States          0
# 1      NaN   4041  United States          0
# 2       gb   7407         France          4
# 3       us   4041  United States          0
# 4       us    383  United States          7
# 5       us   1310  United States          1
# 6       gb   7407         France          4
# 7       us   1061  United States          1
# 8       us    763  United States          0
# 9       us   4596  United States          0
# 10      us  10448  United States          7
# 11      us   2018  United States          0
# 12      us   3506  United States          1
# 13      us   1000  United States          1
# 14      us   2018  United States          0
